# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors

np.random.seed(42)

# %%
# generate 20 data points with 2 dims
X = np.random.rand(20, 2)
print(X)
# lets display the embeddings
n = range(len(X))

fig, ax = plt.subplots()
ax.scatter(X[:,0], X[:,1], label='Embeddings')
ax.legend()

for i, txt in enumerate(n):
    ax.annotate(txt, (X[i,0], X[i,1]))
# Out:
# [[0.38816993 0.64328822]
#  [0.45825289 0.54561679]
#  [0.94146481 0.38610264]
#  [0.96119056 0.90535064]
#  [0.19579113 0.0693613 ]
#  [0.100778   0.01822183]
#  [0.09444296 0.68300677]
#  [0.07118865 0.31897563]
#  [0.84487531 0.02327194]
#  [0.81446848 0.28185477]
#  [0.11816483 0.69673717]
#  [0.62894285 0.87747201]
#  [0.73507104 0.80348093]
#  [0.28203457 0.17743954]
#  [0.75061475 0.80683474]
#  [0.99050514 0.41261768]
#  [0.37201809 0.77641296]
#  [0.34080354 0.93075733]
#  [0.85841275 0.42899403]
#  [0.75087107 0.75454287]]

# %%
# build NN search
k = 4 #--> find the 4 closest neighbors

nn = NearestNeighbors(n_neighbors=k, algorithm='brute', metric='euclidean')
nn.fit(X)
# Out:
# NearestNeighbors(algorithm='brute', metric='euclidean', n_neighbors=4)

# %%
# Display Query with data
n = range(len(X))

# build a query with value 0.45 & 0.2
fig, ax = plt.subplots()
ax.scatter(X[:,0], X[:,1])
ax.scatter(0.45,0.2, c='red',label='Query')
ax.legend()

for i, txt in enumerate(n):
    ax.annotate(txt, (X[i,0], X[i,1]))

# %%
# find the closest points to the query and pringt the index
neighbours = nn.kneighbors([[0.45,0.2]], k, return_distance=True)
print(neighbours)
# Out:
# (array([[0.16947377, 0.28581221, 0.34571531, 0.37354716]]), array([[13,  4,  1,  9]], dtype=int64))
